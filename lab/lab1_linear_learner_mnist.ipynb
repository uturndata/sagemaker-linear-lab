# %% [markdown]
# # An Introduction to Linear Learner with MNIST
# _**Making a Binary Prediction of Whether a Handwritten Digit is a 3**_
#
# 1. [Introduction](#Introduction)
# 2. [Prerequisites and Preprocessing](#Prequisites-and-Preprocessing)
#   1. [Permissions and environment variables](#Permissions-and-environment-variables)
#   2. [Data ingestion](#Data-ingestion)
#   3. [Data inspection](#Data-inspection)
#   4. [Data conversion](#Data-conversion)
# 3. [Training the linear model](#Training-the-linear-model)
# 4. [Set up hosting for the model](#Set-up-hosting-for-the-model)
# 5. [Validate the model for use](#Validate-the-model-for-use)

# %% [markdown]
# ## Introduction
#
# Welcome to our example introducing Amazon SageMaker's Linear Learner Algorithm!  Today, we're analyzing the [MNIST](https://en.wikipedia.org/wiki/MNIST_database) dataset which consists of images of handwritten digits, from zero to nine.  We'll use the individual pixel values from each 28 x 28 grayscale image to predict a yes or no label of whether the handwritten digit is a `3` or some other digit (0, 1, 2, 4, 5, 6, 7, 8, 9).
#
# The method that we'll use is a linear binary classifier.  Linear models are supervised learning algorithms used for solving either classification or regression problems.  As input, the model is given labeled examples ( **`x`**, `y`). **`x`** is a high dimensional vector and `y` is a numeric label.  Since we are doing binary classification here, the algorithm expects the label to be either 0 or 1. The algorithm learns a linear function, or linear threshold function for classification, mapping the vector **`x`** to an approximation of the label `y` (0 or 1).
#
# Amazon SageMaker's Linear Learner algorithm extends upon typical linear models by training many models in parallel, in a computationally efficient manner.  Each model has a different set of hyperparameters, and then the algorithm finds the set that optimizes a specific criteria.  This can provide substantially more accurate models than typical linear algorithms at the same, or lower, cost.
#
# To get started, we need to set up the environment with a few prerequisite steps, for permissions, configurations, and so on.

# %% [markdown]
# ## Prerequisites and Preprocessing
#
# The notebook works with *Data Science* kernel in SageMaker Studio.
#
# ### Permissions and environment variables
#
# Let's start by specifying:
#
# - The S3 bucket and prefix that you want to use for training and model data.  This should be within the same region as the Notebook Instance, training, and hosting.
# - The IAM role arn used to give training and hosting access to your data. This role will be determined automatically using the get_execution_role() function, which will indicate the IAM role that you created when your first provisioned SageMaker Studio.

# %%
import sagemaker

bucket = sagemaker.Session().default_bucket()
prefix = 'sagemaker/DEMO-linear-mnist'
 
# Define IAM role
import boto3
import re
from sagemaker import get_execution_role

role = get_execution_role()

# %% [markdown]
# ### Data ingestion
#
# Next, we read the dataset from an online URL into memory, for preprocessing prior to training. This processing could be done *in situ* by Amazon Athena, Apache Spark in Amazon EMR, Amazon Redshift, etc., assuming the dataset is present in the appropriate location. Then, the next step would be to transfer the data to S3 for use in training. For small datasets, such as this one, reading into memory isn't onerous, though it would be for larger datasets.

# %%
# %%time
import pickle, gzip, numpy, urllib.request, json

# Load the dataset
urllib.request.urlretrieve("https://github.com/mnielsen/neural-networks-and-deep-learning/blob/master/data/mnist.pkl.gz?raw=true", "mnist.pkl.gz")
with gzip.open('mnist.pkl.gz', 'rb') as f:
    train_set, valid_set, test_set = pickle.load(f, encoding='latin1')
# Out:
# CPU times: user 782 ms, sys: 344 ms, total: 1.13 s
# Wall time: 2.38 s

# %% [markdown]
# ### Data inspection
#
# Once the dataset is imported, it's typical as part of the machine learning process to inspect the data, understand the distributions, and determine what type(s) of preprocessing might be needed. You can perform those tasks right here in the notebook. As an example, let's go ahead and look at one of the digits that is part of the dataset.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (4,10)


def show_digit(img, caption='', subplot=None):
    if subplot==None:
        _,(subplot)=plt.subplots(1,1)
    imgr=img.reshape((28,28))
    subplot.axis('off')
    subplot.imshow(imgr, cmap='gray')
    plt.title(caption)

show_digit(train_set[0][30], 'This is a {}'.format(train_set[1][30]))

# %% [markdown]
# ### Data conversion
#
# Since algorithms have particular input and output requirements, converting the dataset is also part of the process that a data scientist goes through prior to initiating training. In this particular case, the Amazon SageMaker implementation of Linear Learner takes recordIO-wrapped protobuf, where the data we have today is a pickle-ized numpy array on disk.
#
# Most of the conversion effort is handled by the Amazon SageMaker Python SDK, imported as `sagemaker` below.

# %%
import io
import numpy as np
import sagemaker.amazon.common as smac

vectors = np.array([t.tolist() for t in train_set[0]]).astype('float32')
labels = np.where(np.array([t.tolist() for t in train_set[1]]) == 3, 1, 0).astype('float32')

buf = io.BytesIO()
smac.write_numpy_to_dense_tensor(buf, vectors, labels)
buf.seek(0)
# Out:
# 0

# %% [markdown]
# ## Upload training data
# Now that we've created our recordIO-wrapped protobuf, we'll need to upload it to S3, so that Amazon SageMaker training can use it.

# %%
import boto3
import os

key = 'recordio-pb-data'
boto3.resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train', key)).upload_fileobj(buf)
s3_train_data = 's3://{}/{}/train/{}'.format(bucket, prefix, key)
print('uploaded training data location: {}'.format(s3_train_data))
# Out:
# uploaded training data location: s3://sagemaker-us-east-2-183121829609/sagemaker/DEMO-linear-mnist/train/recordio-pb-data

# %% [markdown]
# Let's also setup an output S3 location for the model artifact that will be output as the result of training with the algorithm.

# %%
output_location = 's3://{}/{}/output'.format(bucket, prefix)
print('training artifacts will be uploaded to: {}'.format(output_location))
# Out:
# training artifacts will be uploaded to: s3://sagemaker-us-east-2-183121829609/sagemaker/DEMO-linear-mnist/output

# %% [markdown]
# ## Training the linear model
#
# Once we have the data preprocessed and available in the correct format for training, the next step is to actually train the model using the data. Since this data is relatively small, it isn't meant to show off the performance of the Linear Learner training algorithm, although we have tested it on multi-terabyte datasets.
#
# Again, we'll use the Amazon SageMaker Python SDK to kick off training, and monitor status until it is completed.  In this example that takes between 7 and 11 minutes.  Despite the dataset being small, provisioning hardware and loading the algorithm container take time upfront.
#
# First, let's specify our containers.  Since we want this notebook to run in any of Amazon SageMaker's regions, we'll create a small lookup.  More details on algorithm containers can be found in [AWS documentation](https://docs-aws.amazon.com/sagemaker/latest/dg/sagemaker-algo-docker-registry-paths.html).

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
container = get_image_uri(boto3.Session().region_name, 'linear-learner')
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.

# %% [markdown]
# Next we'll kick off the base estimator, making sure to pass in the necessary hyperparameters.
#
# Note:
# - `feature_dim` is set to 784, which is the number of pixels in each 28 x 28 image.
# - `predictor_type` is set to 'binary_classifier' since we are trying to predict whether the image is or is not a 3.
# - `mini_batch_size` is set to 200.  This value can be tuned for relatively minor improvements in fit and speed, but selecting a reasonable value relative to the dataset is appropriate in most cases.

# %%
import boto3

sess = sagemaker.Session()

linear = sagemaker.estimator.Estimator(container,
                                       role, 
                                       train_instance_count=1, 
                                       train_instance_type='ml.c4.xlarge',
                                       output_path=output_location,
                                       sagemaker_session=sess)
linear.set_hyperparameters(feature_dim=784,
                           predictor_type='binary_classifier',
                           mini_batch_size=200)

linear.fit({'train': s3_train_data})
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# 2021-01-25 17:37:46 Starting - Starting the training job...
# 2021-01-25 17:38:09 Starting - Launching requested ML instancesProfilerReport-1611596266: InProgress
# ......
# 2021-01-25 17:39:10 Starting - Preparing the instances for training.........
# 2021-01-25 17:40:44 Downloading - Downloading input data
# 2021-01-25 17:40:44 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [01/25/2021 17:40:48 INFO 140471008261952] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [01/25/2021 17:40:48 INFO 140471008261952] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'784', u'mini_batch_size': u'200', u'predictor_type': u'binary_classifier'}
# [01/25/2021 17:40:48 INFO 140471008261952] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'784', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'200', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [01/25/2021 17:40:48 WARNING 140471008261952] Loggers have already been setup.
# Process 1 is a worker.
# [01/25/2021 17:40:48 INFO 140471008261952] Using default worker.
# [01/25/2021 17:40:49 INFO 140471008261952] Checkpoint loading and saving are disabled.
# [2021-01-25 17:40:49.165] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 34, "num_examples": 1, "num_bytes": 636800}
# [01/25/2021 17:40:49 INFO 140471008261952] Create Store: local
# [2021-01-25 17:40:49.568] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 402, "num_examples": 51, "num_bytes": 32476800}
# [01/25/2021 17:40:49 INFO 140471008261952] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fc1950e8cd0>
# [01/25/2021 17:40:49 INFO 140471008261952] Scaling model computed with parameters:
#  {'stdev_weight':
# [1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 3.94492550e-03
#  1.04610855e-02 1.33176269e-02 1.02671087e-02 1.89491250e-02
#  1.65359322e-02 1.81397479e-02 1.77312214e-02 1.80720985e-02
#  2.26263870e-02 1.72949098e-02 1.77441761e-02 1.38624832e-02
#  1.54940551e-02 9.07990150e-03 7.73912016e-03 7.61912158e-03
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  2.24319263e-03 4.84585791e-04 1.97246275e-03 4.55508707e-03
#  2.29639579e-02 3.39448415e-02 4.29402180e-02 5.23685887e-02
#  6.82234913e-02 7.98171237e-02 8.88206214e-02 1.01305366e-01
#  1.15898423e-01 1.12989835e-01 9.80169475e-02 8.25162008e-02
#  5.89759052e-02 4.34567295e-02 2.49874219e-02 1.34935491e-02
#  4.03929362e-03 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  3.77784553e-03 1.69358458e-02 2.65588202e-02 3.42243798e-02
#  5.25780693e-02 6.86879233e-02 9.47839096e-02 1.18634902e-01
#  1.40737429e-01 1.66125149e-01 1.85117915e-01 2.01920375e-01
#  2.06296414e-01 1.97139218e-01 1.73980132e-01 1.44603163e-01
#  1.06258735e-01 7.99237639e-02 5.08462936e-02 2.65238583e-02
#  1.36450613e-02 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 3.20059783e-03
#  1.45901926e-02 3.13075073e-02 4.58937474e-02 7.50448108e-02
#  1.05263487e-01 1.42169774e-01 1.86635748e-01 2.27824897e-01
#  2.65833706e-01 3.00070584e-01 3.25894147e-01 3.41829926e-01
#  3.42463762e-01 3.27946275e-01 3.03464592e-01 2.60635525e-01
#  2.05971986e-01 1.55582175e-01 1.13750860e-01 7.58975968e-02
#  4.29635681e-02 1.47907427e-02 3.48081696e-04 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 2.93935696e-03 1.51115656e-02
#  3.29358652e-02 6.57071769e-02 9.60143283e-02 1.35235637e-01
#  1.82123125e-01 2.31933147e-01 2.83096194e-01 3.29145193e-01
#  3.67008448e-01 3.99231106e-01 4.17853862e-01 4.24342513e-01
#  4.26379174e-01 4.17568326e-01 3.94363761e-01 3.55644882e-01
#  3.03377479e-01 2.44013295e-01 1.83915734e-01 1.32495791e-01
#  8.74551907e-02 4.33507822e-02 1.33556416e-02 6.96163392e-04
#  1.00000000e+00 1.00000000e+00 7.76072918e-03 2.76757479e-02
#  5.67227043e-02 9.11811665e-02 1.34879202e-01 1.90676540e-01
#  2.46868506e-01 3.02129209e-01 3.53216469e-01 3.92389953e-01
#  4.16605562e-01 4.31067705e-01 4.37365025e-01 4.41249490e-01
#  4.39440429e-01 4.39221919e-01 4.30656374e-01 4.07722294e-01
#  3.61761272e-01 3.06319296e-01 2.40859449e-01 1.77256167e-01
#  1.22995712e-01 7.14610592e-02 3.02156471e-02 1.18679544e-02
#  1.81776099e-03 9.33173113e-03 1.80900171e-02 4.36167121e-02
#  7.67053217e-02 1.23607144e-01 1.74079359e-01 2.33128011e-01
#  2.93940902e-01 3.50558162e-01 3.93199652e-01 4.15627837e-01
#  4.25236702e-01 4.29629087e-01 4.30348128e-01 4.29715633e-01
#  4.31071222e-01 4.32865858e-01 4.31941420e-01 4.24364537e-01
#  3.96579325e-01 3.47653896e-01 2.81905383e-01 2.12364540e-01
#  1.46784306e-01 9.10512730e-02 4.09692377e-02 1.10720564e-02
#  7.38706766e-03 1.69502832e-02 2.96603944e-02 5.78092076e-02
#  1.05509877e-01 1.51767865e-01 2.06245676e-01 2.70226508e-01
#  3.32466841e-01 3.85342121e-01 4.15692836e-01 4.29783225e-01
#  4.34012383e-01 4.35559571e-01 4.35787708e-01 4.32419538e-01
#  4.32698786e-01 4.35421079e-01 4.36579973e-01 4.31350917e-01
#  4.15372491e-01 3.69549870e-01 3.01578254e-01 2.22329885e-01
#  1.49137840e-01 9.14694145e-02 3.23920399e-02 8.82186554e-03
#  1.19894824e-03 1.90961286e-02 3.56134474e-02 6.87012076e-02
#  1.13878332e-01 1.67845502e-01 2.28681266e-01 2.96960264e-01
#  3.59889030e-01 4.04147655e-01 4.27901119e-01 4.35145408e-01
#  4.36418921e-01 4.31494981e-01 4.27002698e-01 4.22120482e-01
#  4.27684844e-01 4.33761090e-01 4.34772104e-01 4.32158500e-01
#  4.15939212e-01 3.72851223e-01 3.00387651e-01 2.07922608e-01
#  1.28391027e-01 6.42759129e-02 2.19067242e-02 5.73158218e-03
#  1.00000000e+00 2.01530941e-02 3.94741297e-02 6.93644360e-02
#  1.13405839e-01 1.70645282e-01 2.35999882e-01 3.05523038e-01
#  3.72269690e-01 4.12820429e-01 4.31253672e-01 4.33602810e-01
#  4.23717797e-01 4.09735233e-01 4.04385388e-01 4.11280185e-01
#  4.22015309e-01 4.29675877e-01 4.30581391e-01 4.30687040e-01
#  4.07417446e-01 3.59438032e-01 2.84420550e-01 1.92011282e-01
#  1.09981179e-01 4.64483313e-02 1.58791281e-02 2.04981444e-03
#  1.00000000e+00 1.04851592e-02 3.80173847e-02 6.77681640e-02
#  1.07945666e-01 1.71286166e-01 2.40526810e-01 3.16523194e-01
#  3.82934034e-01 4.19950128e-01 4.31718022e-01 4.27304059e-01
#  4.09066856e-01 3.94010305e-01 4.01941001e-01 4.14808959e-01
#  4.21882480e-01 4.28273916e-01 4.29794133e-01 4.26058590e-01
#  3.91682118e-01 3.35908264e-01 2.68548399e-01 1.87748045e-01
#  1.04305372e-01 4.02241386e-02 2.12533344e-02 1.08292082e-03
#  1.00000000e+00 1.00112176e-02 2.82707363e-02 5.37265576e-02
#  9.87592936e-02 1.71164855e-01 2.50810295e-01 3.33866268e-01
#  3.94889355e-01 4.24917608e-01 4.31839973e-01 4.25715894e-01
#  4.08126831e-01 4.02041048e-01 4.21552151e-01 4.30972755e-01
#  4.29834664e-01 4.32951361e-01 4.35623735e-01 4.18909818e-01
#  3.77192348e-01 3.21708620e-01 2.62223452e-01 1.94190100e-01
#  1.12322643e-01 3.89801674e-02 1.99374650e-02 3.71287018e-03
#  1.00000000e+00 9.86280106e-03 1.81496162e-02 3.92598845e-02
#  9.34294462e-02 1.76559284e-01 2.69591689e-01 3.51013362e-01
#  4.02812719e-01 4.27507520e-01 4.32988375e-01 4.23787117e-01
#  4.16044772e-01 4.23496246e-01 4.43873614e-01 4.37031209e-01
#  4.29811329e-01 4.35970992e-01 4.35601205e-01 4.11843717e-01
#  3.69036704e-01 3.19448829e-01 2.65287995e-01 2.01888576e-01
#  1.20717429e-01 4.04090285e-02 7.50047434e-03 1.00000000e+00
#  1.00000000e+00 4.67976369e-03 9.96531639e-03 3.44210491e-02
#  9.45271328e-02 1.90941051e-01 2.84894913e-01 3.61630678e-01
#  4.07279700e-01 4.27376866e-01 4.29911733e-01 4.23774391e-01
#  4.22459662e-01 4.35994923e-01 4.43703175e-01 4.27118272e-01
#  4.26644385e-01 4.38567311e-01 4.34852242e-01 4.10224825e-01
#  3.73937458e-01 3.24929148e-01 2.68227905e-01 2.05017433e-01
#  1.22506626e-01 4.50176559e-02 7.62108993e-03 1.00000000e+00
#  1.00000000e+00 2.32054386e-04 9.20575298e-03 3.74859497e-02
#  1.00403078e-01 2.08951607e-01 2.98761904e-01 3.63920152e-01
#  4.05923426e-01 4.26199824e-01 4.26035821e-01 4.22738880e-01
#  4.27782774e-01 4.38919425e-01 4.38770294e-01 4.24572170e-01
#  4.33793157e-01 4.40616667e-01 4.30870563e-01 4.08146024e-01
#  3.76872540e-01 3.28658342e-01 2.71661043e-01 2.04069793e-01
#  1.23419538e-01 4.75159809e-02 1.87039636e-02 2.32054386e-04
#  1.00000000e+00 3.55816842e-03 1.46121653e-02 4.30633724e-02
#  1.16337217e-01 2.23566353e-01 3.06311727e-01 3.64136040e-01
#  3.98461193e-01 4.14042771e-01 4.14940715e-01 4.18315828e-01
#  4.31104004e-01 4.42299932e-01 4.39964354e-01 4.33156490e-01
#  4.37774807e-01 4.34804469e-01 4.26190317e-01 4.09637958e-01
#  3.79669040e-01 3.29323441e-01 2.66756743e-01 1.96854621e-01
#  1.22142516e-01 5.29063754e-02 2.36502886e-02 4.25433216e-04
#  1.00000000e+00 2.75275926e-03 2.19910592e-02 5.58153689e-02
#  1.35455310e-01 2.38594130e-01 3.09096992e-01 3.59269977e-01
#  3.87636125e-01 3.99718255e-01 4.03454840e-01 4.12936360e-01
#  4.24752861e-01 4.33075130e-01 4.37052727e-01 4.37283844e-01
#  4.35459405e-01 4.29879934e-01 4.24114525e-01 4.09037948e-01
#  3.77857178e-01 3.26454788e-01 2.58835465e-01 1.87275320e-01
#  1.21168144e-01 6.50033727e-02 2.86698006e-02 3.63503420e-03
#  1.00000000e+00 6.96163275e-04 2.49386393e-02 7.23880157e-02
#  1.58358768e-01 2.51288056e-01 3.17836136e-01 3.60069126e-01
#  3.79850537e-01 3.91518563e-01 4.01267678e-01 4.09322888e-01
#  4.14236486e-01 4.26342309e-01 4.34745014e-01 4.33905691e-01
#  4.30959105e-01 4.31691229e-01 4.28531677e-01 4.09231365e-01
#  3.69187117e-01 3.15112293e-01 2.44048655e-01 1.71371251e-01
#  1.10449135e-01 5.60242236e-02 1.53466230e-02 6.76992768e-03
#  1.00000000e+00 1.00000000e+00 3.05887461e-02 8.80458131e-02
#  1.71716914e-01 2.62007117e-01 3.30397874e-01 3.69256526e-01
#  3.89117181e-01 4.01139468e-01 4.13360953e-01 4.20257658e-01
#  4.22717273e-01 4.31972921e-01 4.35091466e-01 4.33622122e-01
#  4.31084007e-01 4.34083730e-01 4.26372021e-01 3.97604764e-01
#  3.52505296e-01 2.89563209e-01 2.18649939e-01 1.49916708e-01
#  9.37407240e-02 4.48708124e-02 1.23545434e-02 4.28988039e-03
#  1.00000000e+00 1.50835409e-03 3.47997397e-02 9.18959305e-02
#  1.69907510e-01 2.56383538e-01 3.31546009e-01 3.78374457e-01
#  4.03178424e-01 4.17098701e-01 4.26328897e-01 4.31362152e-01
#  4.33458388e-01 4.35984612e-01 4.35091168e-01 4.35326993e-01
#  4.35005218e-01 4.31360275e-01 4.13945585e-01 3.78624141e-01
#  3.21096003e-01 2.52549678e-01 1.85978875e-01 1.25768527e-01
#  7.87079036e-02 3.45092155e-02 1.39352623e-02 1.93378725e-03
#  1.00000000e+00 2.78465310e-03 3.22530977e-02 7.88924918e-02
#  1.44034386e-01 2.30809659e-01 3.14300448e-01 3.74641836e-01
#  4.07947451e-01 4.27144140e-01 4.35362130e-01 4.33135808e-01
#  4.34356421e-01 4.31999445e-01 4.34135765e-01 4.35558110e-01
#  4.28441972e-01 4.14655238e-01 3.84276271e-01 3.32879990e-01
#  2.70405531e-01 2.07401454e-01 1.49886608e-01 9.68566611e-02
#  6.16969466e-02 2.89664306e-02 1.14726946e-02 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 2.16943659e-02 5.37078306e-02
#  1.02763742e-01 1.73823819e-01 2.57987916e-01 3.33273381e-01
#  3.89094591e-01 4.21987742e-01 4.38015908e-01 4.42052513e-01
#  4.38766658e-01 4.37678665e-01 4.38338399e-01 4.32226747e-01
#  4.11157072e-01 3.78847182e-01 3.30883265e-01 2.71805763e-01
#  2.11537763e-01 1.60093278e-01 1.13874733e-01 7.19486699e-02
#  4.39616479e-02 2.10775882e-02 6.10366603e-03 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 5.77727053e-03 2.51513571e-02
#  6.01222143e-02 1.08414136e-01 1.74756184e-01 2.49787211e-01
#  3.23381543e-01 3.76828671e-01 4.10625458e-01 4.28288579e-01
#  4.30554032e-01 4.25631940e-01 4.18370575e-01 3.93252224e-01
#  3.55806261e-01 3.05945784e-01 2.52188265e-01 2.03128546e-01
#  1.57345042e-01 1.15941033e-01 7.96129629e-02 5.03237098e-02
#  1.66886058e-02 3.65128578e-03 3.24876350e-03 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.63300186e-02
#  3.99022102e-02 6.71634078e-02 1.07849061e-01 1.58636972e-01
#  2.14336604e-01 2.74235785e-01 3.19748670e-01 3.44148219e-01
#  3.49004447e-01 3.46731484e-01 3.29878896e-01 2.94327945e-01
#  2.59320974e-01 2.18367904e-01 1.79865524e-01 1.45078033e-01
#  1.16880730e-01 8.47071484e-02 5.53058349e-02 3.47583294e-02
#  1.50805498e-02 1.35365094e-03 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 2.45967391e-03
#  1.70110669e-02 4.11987118e-02 6.91738352e-02 1.01292245e-01
#  1.44580290e-01 1.82481498e-01 2.12960392e-01 2.19844192e-01
#  2.22073749e-01 2.21406013e-01 2.08605841e-01 1.86790422e-01
#  1.71107888e-01 1.48116753e-01 1.21893883e-01 1.00215897e-01
#  7.93611184e-02 5.65856993e-02 3.35968845e-02 2.18519438e-02
#  5.58676105e-03 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.46967848e-03
#  1.05320141e-02 2.14112904e-02 4.39937375e-02 6.59096837e-02
#  9.34475884e-02 1.14821352e-01 1.27970278e-01 1.30696684e-01
#  1.26551583e-01 1.26627609e-01 1.26468301e-01 1.06794536e-01
#  9.68687087e-02 8.43336359e-02 7.16911405e-02 5.94058782e-02
#  4.67881113e-02 3.16491798e-02 1.87638719e-02 7.71086058e-03
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 6.84560649e-03 1.00246007e-02 1.74784493e-02
#  2.19308790e-02 2.16455013e-02 2.81812716e-02 3.65256816e-02
#  4.40249480e-02 4.45496589e-02 4.55292128e-02 3.93585563e-02
#  3.22563127e-02 2.38721371e-02 2.29482837e-02 1.43505000e-02
#  1.28365206e-02 8.07273109e-03 7.92295765e-03 1.00000000e+00
#  1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00]
# <NDArray 784 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 3.90625028e-05
#  1.32889123e-04 2.12545914e-04 2.20588292e-04 4.37346840e-04
#  4.09773231e-04 4.72962623e-04 4.15517774e-04 5.31939266e-04
#  6.38020982e-04 4.27389663e-04 3.56923905e-04 3.15946672e-04
#  3.02159897e-04 1.42080273e-04 1.08379281e-04 7.54442444e-05
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  2.22120143e-05 6.51041682e-06 1.95312514e-05 1.03017774e-04
#  7.32230430e-04 1.57130824e-03 2.47051148e-03 3.84382624e-03
#  6.16153423e-03 8.27282388e-03 1.08363954e-02 1.39410989e-02
#  1.73958354e-02 1.66976880e-02 1.28461989e-02 8.66957568e-03
#  4.60631074e-03 2.31617643e-03 9.10692499e-04 2.82245717e-04
#  5.93596778e-05 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  4.82536743e-05 4.38112766e-04 9.07628739e-04 1.66743260e-03
#  3.62936594e-03 6.43727044e-03 1.21074598e-02 1.88530199e-02
#  2.66567096e-02 3.65372300e-02 4.59099337e-02 5.50080538e-02
#  5.73376231e-02 5.18887974e-02 4.03002501e-02 2.76489742e-02
#  1.52611826e-02 8.10087286e-03 3.67302471e-03 1.11711072e-03
#  3.91773909e-04 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 4.48069877e-05
#  3.41222534e-04 1.71568606e-03 3.50030605e-03 8.14491417e-03
#  1.56544875e-02 2.86845118e-02 4.83670309e-02 7.23407120e-02
#  1.01020999e-01 1.33289650e-01 1.62758857e-01 1.81522310e-01
#  1.83595344e-01 1.66121781e-01 1.35376498e-01 9.75677967e-02
#  5.99628538e-02 3.41015644e-02 1.84110757e-02 8.35784432e-03
#  2.97602639e-03 4.69132967e-04 3.44669206e-06 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 2.91053893e-05 3.81433871e-04
#  1.75551476e-03 5.74257039e-03 1.25919124e-02 2.49088537e-02
#  4.51240875e-02 7.51478225e-02 1.15662917e-01 1.63785979e-01
#  2.17636332e-01 2.78250545e-01 3.28077555e-01 3.55426341e-01
#  3.54569584e-01 3.26203197e-01 2.71575481e-01 2.04266593e-01
#  1.37503117e-01 8.55721459e-02 4.86711077e-02 2.50899959e-02
#  1.13591421e-02 3.13763833e-03 4.08241438e-04 6.89338503e-06
#  0.00000000e+00 0.00000000e+00 1.27910535e-04 1.17225817e-03
#  4.43704007e-03 1.12787224e-02 2.50107199e-02 4.93233055e-02
#  8.46358016e-02 1.33169040e-01 1.96388662e-01 2.64108837e-01
#  3.33429158e-01 4.03901666e-01 4.60013002e-01 4.86333936e-01
#  4.79071230e-01 4.41563368e-01 3.81979197e-01 3.01045179e-01
#  2.11790368e-01 1.39361590e-01 8.36182684e-02 4.40996476e-02
#  2.17700712e-02 7.55936047e-03 1.46790745e-03 2.66544113e-04
#  1.79993876e-05 1.64292273e-04 4.95174667e-04 2.76692701e-03
#  8.63549486e-03 2.04936378e-02 4.16942388e-02 7.59351924e-02
#  1.28435969e-01 1.97459787e-01 2.75440365e-01 3.52621377e-01
#  4.23433721e-01 4.82485831e-01 5.17372906e-01 5.28684556e-01
#  5.20964563e-01 4.98504639e-01 4.51166153e-01 3.74432474e-01
#  2.80243129e-01 1.89844146e-01 1.15545332e-01 6.26642853e-02
#  3.01079992e-02 1.19734202e-02 2.55744485e-03 2.16375629e-04
#  7.31464388e-05 3.79519071e-04 1.17455551e-03 4.91115265e-03
#  1.47813242e-02 3.07169110e-02 5.83739318e-02 1.04968227e-01
#  1.70094207e-01 2.52433330e-01 3.39439034e-01 4.15227443e-01
#  4.66429293e-01 4.86376077e-01 4.85968858e-01 4.78029579e-01
#  4.78621274e-01 4.82984066e-01 4.66659456e-01 4.05716091e-01
#  3.17226261e-01 2.20420867e-01 1.33341417e-01 6.87564835e-02
#  3.04760262e-02 1.17689194e-02 1.78806693e-03 1.41314362e-04
#  1.18719363e-05 5.61044726e-04 1.90295628e-03 6.23506308e-03
#  1.71511248e-02 3.74770202e-02 7.15031177e-02 1.26650587e-01
#  2.02949598e-01 2.94427514e-01 3.79658788e-01 4.32254910e-01
#  4.38242137e-01 4.15262312e-01 3.93862665e-01 3.87077212e-01
#  4.06341642e-01 4.39446598e-01 4.44381922e-01 4.01194066e-01
#  3.18853021e-01 2.19575286e-01 1.30831435e-01 6.14755712e-02
#  2.33264416e-02 6.70764316e-03 8.67800205e-04 7.88909238e-05
#  0.00000000e+00 5.25811862e-04 2.00367649e-03 6.22357521e-03
#  1.70232039e-02 3.90058272e-02 7.54829273e-02 1.36563689e-01
#  2.24274233e-01 3.16170424e-01 3.88575464e-01 4.07194078e-01
#  3.71892601e-01 3.31032872e-01 3.14777911e-01 3.29337537e-01
#  3.65734577e-01 4.14378464e-01 4.22445983e-01 3.82889181e-01
#  2.95634151e-01 1.97893709e-01 1.14763714e-01 5.18550836e-02
#  1.68543253e-02 3.42869200e-03 4.43091325e-04 2.02971787e-05
#  0.00000000e+00 2.07184479e-04 1.94431690e-03 5.79695264e-03
#  1.55070489e-02 3.86274494e-02 7.87140131e-02 1.48641601e-01
#  2.41823688e-01 3.33093256e-01 3.86814862e-01 3.75730783e-01
#  3.25647891e-01 2.93674231e-01 2.95394480e-01 3.27838182e-01
#  3.76086175e-01 4.22431856e-01 4.14441288e-01 3.60018104e-01
#  2.64072478e-01 1.69874787e-01 9.94791612e-02 4.76409346e-02
#  1.53029282e-02 2.47587333e-03 6.41084567e-04 1.07230408e-05
#  0.00000000e+00 1.35186885e-04 1.09183521e-03 3.96254519e-03
#  1.31809143e-02 3.91624533e-02 8.78136382e-02 1.66480169e-01
#  2.61925936e-01 3.49522948e-01 3.84906143e-01 3.62014413e-01
#  3.17119747e-01 3.07949215e-01 3.40878874e-01 3.86790723e-01
#  4.38486993e-01 4.57743973e-01 4.20700818e-01 3.38735342e-01
#  2.38151044e-01 1.52724415e-01 9.33498070e-02 4.89954762e-02
#  1.73000898e-02 2.29702820e-03 5.73299709e-04 3.67647008e-05
#  0.00000000e+00 1.09145214e-04 4.70664818e-04 2.36251554e-03
#  1.21591613e-02 4.23525535e-02 1.01402044e-01 1.85072735e-01
#  2.78429031e-01 3.58133405e-01 3.83456230e-01 3.63861024e-01
#  3.43767256e-01 3.75709593e-01 4.27707583e-01 4.77439970e-01
#  5.08730531e-01 4.91583139e-01 4.22190994e-01 3.21526974e-01
#  2.25145176e-01 1.49216115e-01 9.45909917e-02 5.30058965e-02
#  1.96327381e-02 2.45787320e-03 1.63909339e-04 0.00000000e+00
#  0.00000000e+00 4.63388387e-05 1.23314967e-04 1.82559795e-03
#  1.24268550e-02 5.01930043e-02 1.13691024e-01 1.98525205e-01
#  2.87391603e-01 3.53973240e-01 3.77128184e-01 3.71904790e-01
#  3.87973756e-01 4.50541943e-01 5.05334973e-01 5.47347963e-01
#  5.45139909e-01 5.03177166e-01 4.16105539e-01 3.13716203e-01
#  2.25746006e-01 1.54364645e-01 9.82486829e-02 5.54687455e-02
#  2.02895179e-02 2.71369447e-03 1.53569243e-04 0.00000000e+00
#  0.00000000e+00 2.29779380e-06 1.29059437e-04 2.10937555e-03
#  1.44427847e-02 5.94948679e-02 1.24456182e-01 2.03150302e-01
#  2.82244265e-01 3.39428633e-01 3.61441463e-01 3.73201638e-01
#  4.13510561e-01 4.79015738e-01 5.25484145e-01 5.51089644e-01
#  5.29901445e-01 4.84033346e-01 3.98011208e-01 3.07428747e-01
#  2.29727298e-01 1.59011200e-01 1.01290599e-01 5.55250607e-02
#  2.09635403e-02 3.30805802e-03 6.07383670e-04 2.29779380e-06
#  0.00000000e+00 3.52328461e-05 3.56541073e-04 2.86688097e-03
#  1.92647092e-02 6.81977794e-02 1.32639065e-01 2.02236533e-01
#  2.66284138e-01 3.10493231e-01 3.30831468e-01 3.53237182e-01
#  3.96811783e-01 4.52369422e-01 5.01086891e-01 5.13104260e-01
#  4.88676906e-01 4.44411755e-01 3.77638668e-01 3.06069881e-01
#  2.33306155e-01 1.60425469e-01 9.89686847e-02 5.22671677e-02
#  2.06602290e-02 4.22526104e-03 8.13419116e-04 4.21262212e-06
#  0.00000000e+00 2.91053966e-05 6.36489014e-04 4.48491052e-03
#  2.55284961e-02 7.75854066e-02 1.36625275e-01 1.97816685e-01
#  2.47107103e-01 2.77965337e-01 2.96399385e-01 3.19282353e-01
#  3.50133717e-01 4.02653247e-01 4.52548563e-01 4.65458453e-01
#  4.49672937e-01 4.15680856e-01 3.64384174e-01 3.02985251e-01
#  2.30487153e-01 1.56144321e-01 9.35650393e-02 4.72882167e-02
#  2.03730091e-02 5.83065255e-03 1.16766256e-03 4.28921630e-05
#  0.00000000e+00 6.89338322e-06 9.94562171e-04 7.52182771e-03
#  3.35301757e-02 8.56223106e-02 1.45067796e-01 1.99473783e-01
#  2.35507846e-01 2.61963904e-01 2.82924294e-01 2.99275845e-01
#  3.24255556e-01 3.79102319e-01 4.27750945e-01 4.45426702e-01
#  4.39175487e-01 4.13512558e-01 3.66264582e-01 2.98041195e-01
#  2.16834426e-01 1.43233776e-01 8.28910097e-02 4.05553095e-02
#  1.69791672e-02 4.69975406e-03 5.36534877e-04 1.08379281e-04
#  0.00000000e+00 0.00000000e+00 1.47863047e-03 1.05024530e-02
#  3.88499498e-02 9.34677348e-02 1.57761589e-01 2.12396592e-01
#  2.50571787e-01 2.80267268e-01 3.06436479e-01 3.22650909e-01
#  3.54604751e-01 4.07702595e-01 4.49304849e-01 4.61061954e-01
#  4.51730251e-01 4.17679965e-01 3.57743561e-01 2.75059015e-01
#  1.91341892e-01 1.19954430e-01 6.51554689e-02 3.06713358e-02
#  1.24111539e-02 3.04534379e-03 2.64246366e-04 5.66789349e-05
#  0.00000000e+00 1.49356611e-05 1.80798105e-03 1.13239149e-02
#  3.78412306e-02 8.95664990e-02 1.60410985e-01 2.24792436e-01
#  2.76505113e-01 3.20614636e-01 3.55537355e-01 3.83608669e-01
#  4.24673319e-01 4.70654905e-01 4.94765192e-01 4.90774363e-01
#  4.57127720e-01 3.98746967e-01 3.19976181e-01 2.32536376e-01
#  1.52743593e-01 8.96327496e-02 4.66409959e-02 2.18301974e-02
#  8.79289117e-03 1.87768089e-03 2.77267158e-04 1.91482868e-05
#  0.00000000e+00 2.75735292e-05 1.44454686e-03 8.61136615e-03
#  2.81575508e-02 7.28680342e-02 1.42569661e-01 2.17411548e-01
#  2.84816533e-01 3.49293470e-01 4.02283698e-01 4.48456973e-01
#  4.89529699e-01 5.18406332e-01 5.15267789e-01 4.79520887e-01
#  4.16718781e-01 3.33896667e-01 2.47254178e-01 1.69138685e-01
#  1.05075076e-01 5.93033880e-02 3.05147059e-02 1.32747395e-02
#  5.40058129e-03 1.18336384e-03 1.95695480e-04 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 6.89721142e-04 4.46806056e-03
#  1.50172366e-02 4.30227481e-02 9.59244817e-02 1.68278575e-01
#  2.48389974e-01 3.26328903e-01 3.99626195e-01 4.50407475e-01
#  4.80903089e-01 4.85644221e-01 4.57765013e-01 4.01768148e-01
#  3.22133869e-01 2.39229485e-01 1.66479781e-01 1.05612762e-01
#  6.22487776e-02 3.48900855e-02 1.77856963e-02 7.40387524e-03
#  2.83203134e-03 7.15762726e-04 8.99969309e-05 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 8.34865205e-05 1.21553300e-03
#  5.77895157e-03 1.76428445e-02 4.55882400e-02 9.32050496e-02
#  1.61846310e-01 2.38669991e-01 3.12052697e-01 3.65406603e-01
#  3.85710388e-01 3.74680609e-01 3.38445187e-01 2.77131677e-01
#  2.06985682e-01 1.43368244e-01 9.18692499e-02 5.69282286e-02
#  3.30288820e-02 1.80342402e-02 8.76416918e-03 3.63855646e-03
#  6.64828462e-04 6.77849384e-05 3.21691114e-05 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 4.98621317e-04
#  2.30277330e-03 6.36450620e-03 1.66011825e-02 3.54247056e-02
#  6.55170009e-02 1.07647046e-01 1.51787311e-01 1.81880772e-01
#  1.92358285e-01 1.88761488e-01 1.67838186e-01 1.32023245e-01
#  9.76650640e-02 6.70833588e-02 4.43386212e-02 2.78511792e-02
#  1.74919553e-02 9.28232633e-03 4.24862234e-03 1.78461999e-03
#  3.79519042e-04 1.34037991e-05 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 3.40839506e-05
#  5.13556937e-04 2.46017147e-03 6.41352683e-03 1.37603404e-02
#  2.69841459e-02 4.30097245e-02 5.83812110e-02 6.39866665e-02
#  6.54944107e-02 6.55058995e-02 5.88855632e-02 4.75118682e-02
#  3.88442092e-02 2.87913624e-02 1.97437946e-02 1.30062811e-02
#  8.11121147e-03 4.20726184e-03 1.75666343e-03 7.11933186e-04
#  1.27527572e-04 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.45526928e-05
#  1.65824138e-04 7.04656937e-04 2.70641805e-03 5.82452444e-03
#  1.14096981e-02 1.67432539e-02 2.12630220e-02 2.22717579e-02
#  2.14824583e-02 2.16463711e-02 2.10447311e-02 1.60512403e-02
#  1.24433218e-02 9.48874373e-03 6.86351024e-03 4.50291065e-03
#  2.64667580e-03 1.34420977e-03 5.23513998e-04 1.37867624e-04
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.77849312e-05 1.59696734e-04 4.05177765e-04
#  5.83639659e-04 6.18489634e-04 1.12515315e-03 1.73866400e-03
#  2.49387301e-03 2.61565554e-03 2.74969381e-03 2.16490543e-03
#  1.54028763e-03 9.95710841e-04 7.60186929e-04 3.86795378e-04
#  2.17141554e-04 1.32123183e-04 1.29059437e-04 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# <NDArray 784 @cpu(0)>}
# [01/25/2021 17:40:49 INFO 140471008261952] nvidia-smi took: 0.0252239704132 secs to identify 0 gpus
# [01/25/2021 17:40:49 INFO 140471008261952] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 51, "sum": 51.0, "min": 51}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 52, "sum": 52.0, "min": 52}, "Total Records Seen": {"count": 1, "max": 10400, "sum": 10400.0, "min": 10400}, "Max Records Seen Between Resets": {"count": 1, "max": 10200, "sum": 10200.0, "min": 10200}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1611596449.703993, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1611596449.703954}
#
# [2021-01-25 17:40:57.132] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 7427, "num_examples": 250, "num_bytes": 159200000}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.19091778350830077, "sum": 0.19091778350830077, "min": 0.19091778350830077}}, "EndTime": 1611596457.132576, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.132463}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1900182786178589, "sum": 0.1900182786178589, "min": 0.1900182786178589}}, "EndTime": 1611596457.132679, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.132657}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.18791775774002076, "sum": 0.18791775774002076, "min": 0.18791775774002076}}, "EndTime": 1611596457.132753, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.132733}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.18717440326690674, "sum": 0.18717440326690674, "min": 0.18717440326690674}}, "EndTime": 1611596457.132819, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.132801}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3285735443162918, "sum": 0.3285735443162918, "min": 0.3285735443162918}}, "EndTime": 1611596457.132882, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.132864}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.338232703371048, "sum": 0.338232703371048, "min": 0.338232703371048}}, "EndTime": 1611596457.132944, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.132927}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3341345733165741, "sum": 0.3341345733165741, "min": 0.3341345733165741}}, "EndTime": 1611596457.133002, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.132985}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3354594813156128, "sum": 0.3354594813156128, "min": 0.3354594813156128}}, "EndTime": 1611596457.133062, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.133044}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.185735717754364, "sum": 0.185735717754364, "min": 0.185735717754364}}, "EndTime": 1611596457.133123, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.133106}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.18422947261810302, "sum": 0.18422947261810302, "min": 0.18422947261810302}}, "EndTime": 1611596457.133183, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.133166}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.18504074979782104, "sum": 0.18504074979782104, "min": 0.18504074979782104}}, "EndTime": 1611596457.133249, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.13323}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.18472265594482423, "sum": 0.18472265594482423, "min": 0.18472265594482423}}, "EndTime": 1611596457.133304, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.133286}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.299587965221405, "sum": 0.299587965221405, "min": 0.299587965221405}}, "EndTime": 1611596457.133387, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.133368}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3071275101566315, "sum": 0.3071275101566315, "min": 0.3071275101566315}}, "EndTime": 1611596457.133449, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.133432}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.30302338403701784, "sum": 0.30302338403701784, "min": 0.30302338403701784}}, "EndTime": 1611596457.133517, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.1335}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3136282953834534, "sum": 0.3136282953834534, "min": 0.3136282953834534}}, "EndTime": 1611596457.133578, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.13356}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.20945425888061522, "sum": 0.20945425888061522, "min": 0.20945425888061522}}, "EndTime": 1611596457.133638, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.133621}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.20735999389648438, "sum": 0.20735999389648438, "min": 0.20735999389648438}}, "EndTime": 1611596457.133713, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.133695}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.20853925575256346, "sum": 0.20853925575256346, "min": 0.20853925575256346}}, "EndTime": 1611596457.133755, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.133745}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.20835835529327393, "sum": 0.20835835529327393, "min": 0.20835835529327393}}, "EndTime": 1611596457.133798, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.133783}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.22463699409484864, "sum": 0.22463699409484864, "min": 0.22463699409484864}}, "EndTime": 1611596457.133858, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.133841}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.2362929013824463, "sum": 0.2362929013824463, "min": 0.2362929013824463}}, "EndTime": 1611596457.133912, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.133895}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.2248378853225708, "sum": 0.2248378853225708, "min": 0.2248378853225708}}, "EndTime": 1611596457.133971, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.133955}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.2317411571121216, "sum": 0.2317411571121216, "min": 0.2317411571121216}}, "EndTime": 1611596457.134028, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.13401}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3463905973815918, "sum": 0.3463905973815918, "min": 0.3463905973815918}}, "EndTime": 1611596457.134088, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.134072}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.34841003189086917, "sum": 0.34841003189086917, "min": 0.34841003189086917}}, "EndTime": 1611596457.13414, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.134128}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.34828166275024414, "sum": 0.34828166275024414, "min": 0.34828166275024414}}, "EndTime": 1611596457.134174, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.134165}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.34531452964782716, "sum": 0.34531452964782716, "min": 0.34531452964782716}}, "EndTime": 1611596457.134233, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.134217}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3355793787384033, "sum": 0.3355793787384033, "min": 0.3355793787384033}}, "EndTime": 1611596457.134294, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.134277}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3359659634399414, "sum": 0.3359659634399414, "min": 0.3359659634399414}}, "EndTime": 1611596457.134329, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.13432}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3354189114379883, "sum": 0.3354189114379883, "min": 0.3354189114379883}}, "EndTime": 1611596457.134364, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.134356}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.33482032791137695, "sum": 0.33482032791137695, "min": 0.33482032791137695}}, "EndTime": 1611596457.134409, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596457.134394}
#
# [01/25/2021 17:40:57 INFO 140471008261952] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.190917783508
# [01/25/2021 17:40:57 INFO 140471008261952] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.184229472618
# [01/25/2021 17:40:57 INFO 140471008261952] Epoch 0: Loss improved. Updating best model
# [01/25/2021 17:40:57 INFO 140471008261952] Saving model for epoch: 0
# [01/25/2021 17:40:57 INFO 140471008261952] Saved checkpoint to "/tmp/tmpVftu_Q/mx-mod-0000.params"
# [01/25/2021 17:40:57 INFO 140471008261952] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 250, "sum": 250.0, "min": 250}, "Number of Batches Since Last Reset": {"count": 1, "max": 250, "sum": 250.0, "min": 250}, "Number of Records Since Last Reset": {"count": 1, "max": 50000, "sum": 50000.0, "min": 50000}, "Total Batches Seen": {"count": 1, "max": 302, "sum": 302.0, "min": 302}, "Total Records Seen": {"count": 1, "max": 60400, "sum": 60400.0, "min": 60400}, "Max Records Seen Between Resets": {"count": 1, "max": 50000, "sum": 50000.0, "min": 50000}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1611596457.144965, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1611596449.704271}
#
# [01/25/2021 17:40:57 INFO 140471008261952] #throughput_metric: host=algo-1, train throughput=6719.69317612 records/second
# [2021-01-25 17:41:05.341] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 8195, "num_examples": 250, "num_bytes": 159200000}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0965566816329956, "sum": 0.0965566816329956, "min": 0.0965566816329956}}, "EndTime": 1611596465.341379, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1611596465.341276}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0957347594833374, "sum": 0.0957347594833374, "min": 0.0957347594833374}}, "EndTime": 1611596465.341497, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1611596465.341473}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.09646379326820373, "sum": 0.09646379326820373, "min": 0.09646379326820373}}, "EndTime": 1611596465.341583, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1611596465.341561}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.09605788843154907, "sum": 0.09605788843154907, "min": 0.09605788843154907}}, "EndTime": 1611596465.341662, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1611596465.341643}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.24645176536083221, "sum": 0.24645176536083221, "min": 0.24645176536083221}}, "EndTime": 1611596465.341733, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1611596465.341715}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3154801242470741, "sum": 0.3154801242470741, "min": 0.3154801242470741}}, "EndTime": 1611596465.341799, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1611596465.341782}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.25334330318450926, "sum": 0.25334330318450926, "min": 0.25334330318450926}}, "EndTime": 1611596465.341847, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1611596465.341832}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.30798005431890485, "sum": 0.30798005431890485, "min": 0.30798005431890485}}, "EndTime": 1611596465.341912, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1611596465.341894}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.09667567569732666, "sum": 0.09667567569732666, "min": 0.09667567569732666}}, "EndTime": 1611596465.341967, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1611596465.34195}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.09643363927841186, "sum": 0.09643363927841186, "min": 0.09643363927841186}}, "EndTime": 1611596465.342024, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1611596465.342008}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.09634644277572632, "sum": 0.09634644277572632, "min": 0.09634644277572632}}, "EndTime": 1611596465.342105, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1611596465.342086}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.09657096845626831, "sum": 0.09657096845626831, "min": 0.09657096845626831}}, "EndTime": 1611596465.342169, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1611596465.342152}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.22299541979789733, "sum": 0.22299541979789733, "min": 0.22299541979789733}}, "EndTime": 1611596465.342233, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1611596465.342214}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.2804560758113861, "sum": 0.2804560758113861, "min": 0.2804560758113861}}, "EndTime": 1611596465.3423, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1611596465.342282}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.07824590511322022, "sum": 0.07824590511322022, "min": 0.07824590511322022}}, "EndTime": 1611596559.85072, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.850701}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.08388448554515839, "sum": 0.08388448554515839, "min": 0.08388448554515839}}, "EndTime": 1611596559.850789, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.85077}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.08273551664829254, "sum": 0.08273551664829254, "min": 0.08273551664829254}}, "EndTime": 1611596559.85086, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.850841}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.262404124250412, "sum": 0.262404124250412, "min": 0.262404124250412}}, "EndTime": 1611596559.850916, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.850899}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.08294708521842957, "sum": 0.08294708521842957, "min": 0.08294708521842957}}, "EndTime": 1611596559.850977, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.850959}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.26786283876419065, "sum": 0.26786283876419065, "min": 0.26786283876419065}}, "EndTime": 1611596559.851035, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.851019}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.08284818588256836, "sum": 0.08284818588256836, "min": 0.08284818588256836}}, "EndTime": 1611596559.85109, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.851075}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.08977739419937134, "sum": 0.08977739419937134, "min": 0.08977739419937134}}, "EndTime": 1611596559.851153, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.851135}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.08284579651832581, "sum": 0.08284579651832581, "min": 0.08284579651832581}}, "EndTime": 1611596559.851211, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.851194}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.08975370860099792, "sum": 0.08975370860099792, "min": 0.08975370860099792}}, "EndTime": 1611596559.851263, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.851247}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.08810301204681396, "sum": 0.08810301204681396, "min": 0.08810301204681396}}, "EndTime": 1611596559.851324, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.851307}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.23664995283603668, "sum": 0.23664995283603668, "min": 0.23664995283603668}}, "EndTime": 1611596559.851387, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.851369}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.08810123322486878, "sum": 0.08810123322486878, "min": 0.08810123322486878}}, "EndTime": 1611596559.851459, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.851441}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.24703191020011903, "sum": 0.24703191020011903, "min": 0.24703191020011903}}, "EndTime": 1611596559.851518, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.851502}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.16304437934875488, "sum": 0.16304437934875488, "min": 0.16304437934875488}}, "EndTime": 1611596559.851576, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.85156}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1653486521911621, "sum": 0.1653486521911621, "min": 0.1653486521911621}}, "EndTime": 1611596559.851634, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.851618}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1630444044494629, "sum": 0.1630444044494629, "min": 0.1630444044494629}}, "EndTime": 1611596559.851701, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.851684}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.16533749629974365, "sum": 0.16533749629974365, "min": 0.16533749629974365}}, "EndTime": 1611596559.851762, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.851745}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1646197617340088, "sum": 0.1646197617340088, "min": 0.1646197617340088}}, "EndTime": 1611596559.851821, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.851804}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1996053620147705, "sum": 0.1996053620147705, "min": 0.1996053620147705}}, "EndTime": 1611596559.851883, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.851864}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.16461765434265135, "sum": 0.16461765434265135, "min": 0.16461765434265135}}, "EndTime": 1611596559.851944, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.851926}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1997583349609375, "sum": 0.1997583349609375, "min": 0.1997583349609375}}, "EndTime": 1611596559.852007, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.85199}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.32211975296020506, "sum": 0.32211975296020506, "min": 0.32211975296020506}}, "EndTime": 1611596559.852068, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.852051}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.32209443717956543, "sum": 0.32209443717956543, "min": 0.32209443717956543}}, "EndTime": 1611596559.852131, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.852114}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.32212035995483396, "sum": 0.32212035995483396, "min": 0.32212035995483396}}, "EndTime": 1611596559.8522, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.852182}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3221170576477051, "sum": 0.3221170576477051, "min": 0.3221170576477051}}, "EndTime": 1611596559.852273, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.852253}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3222408241271973, "sum": 0.3222408241271973, "min": 0.3222408241271973}}, "EndTime": 1611596559.852339, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.852321}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3254768204498291, "sum": 0.3254768204498291, "min": 0.3254768204498291}}, "EndTime": 1611596559.852399, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.852383}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.32224177551269534, "sum": 0.32224177551269534, "min": 0.32224177551269534}}, "EndTime": 1611596559.852437, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.852428}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3253067497253418, "sum": 0.3253067497253418, "min": 0.3253067497253418}}, "EndTime": 1611596559.852498, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596559.852483}
#
# [01/25/2021 17:42:39 INFO 140471008261952] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy_objective <loss>=0.0782438310337
# [01/25/2021 17:42:39 INFO 140471008261952] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_cross_entropy_objective, value=0.0782438310337
# [01/25/2021 17:42:39 INFO 140471008261952] Epoch 14: Loss improved. Updating best model
# [01/25/2021 17:42:39 INFO 140471008261952] Saving model for epoch: 14
# [01/25/2021 17:42:39 INFO 140471008261952] Saved checkpoint to "/tmp/tmpuBnPWB/mx-mod-0000.params"
# [01/25/2021 17:42:39 INFO 140471008261952] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 250, "sum": 250.0, "min": 250}, "Number of Batches Since Last Reset": {"count": 1, "max": 250, "sum": 250.0, "min": 250}, "Number of Records Since Last Reset": {"count": 1, "max": 50000, "sum": 50000.0, "min": 50000}, "Total Batches Seen": {"count": 1, "max": 3802, "sum": 3802.0, "min": 3802}, "Total Records Seen": {"count": 1, "max": 760400, "sum": 760400.0, "min": 760400}, "Max Records Seen Between Resets": {"count": 1, "max": 50000, "sum": 50000.0, "min": 50000}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1611596559.860027, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1611596552.672764}
#
# [01/25/2021 17:42:39 INFO 140471008261952] #throughput_metric: host=algo-1, train throughput=6956.63573483 records/second
# [01/25/2021 17:42:39 WARNING 140471008261952] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [01/25/2021 17:42:39 WARNING 140471008261952] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-01-25 17:42:39.864] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 2, "num_examples": 1, "num_bytes": 636800}
# [2021-01-25 17:42:40.486] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 619, "num_examples": 250, "num_bytes": 159200000}
# [2021-01-25 17:42:41.221] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 710, "num_examples": 250, "num_bytes": 159200000}
# [01/25/2021 17:42:41 INFO 140471008261952] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.07782629677772522)
# [01/25/2021 17:42:41 INFO 140471008261952] #train_score (algo-1) : ('binary_classification_accuracy', 0.97646)
# [01/25/2021 17:42:41 INFO 140471008261952] #train_score (algo-1) : ('binary_f_1.000', 0.8795907928388746)
# [01/25/2021 17:42:41 INFO 140471008261952] #train_score (algo-1) : ('precision', 0.9197689345314506)
# [01/25/2021 17:42:41 INFO 140471008261952] #train_score (algo-1) : ('recall', 0.8427759262889629)
# [01/25/2021 17:42:41 INFO 140471008261952] #train_score (algo-1) : ('roc_auc_score', 0.9812665228772263)
# [01/25/2021 17:42:41 INFO 140471008261952] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.0778262967777
# [01/25/2021 17:42:41 INFO 140471008261952] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.97646
# [01/25/2021 17:42:41 INFO 140471008261952] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.879590792839
# [01/25/2021 17:42:41 INFO 140471008261952] #quality_metric: host=algo-1, train precision <score>=0.919768934531
# [01/25/2021 17:42:41 INFO 140471008261952] #quality_metric: host=algo-1, train recall <score>=0.842775926289
# [01/25/2021 17:42:41 INFO 140471008261952] #quality_metric: host=algo-1, train roc_auc_score <score>=0.981266522877
# [01/25/2021 17:42:41 INFO 140471008261952] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.005, "lr_scheduler_minimum_lr": 1e-05}
# [01/25/2021 17:42:41 INFO 140471008261952] Saved checkpoint to "/tmp/tmpnEXQHa/mx-mod-0000.params"
# [01/25/2021 17:42:41 INFO 140471008261952] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 112421.56982421875, "sum": 112421.56982421875, "min": 112421.56982421875}, "finalize.time": {"count": 1, "max": 1379.0202140808105, "sum": 1379.0202140808105, "min": 1379.0202140808105}, "initialize.time": {"count": 1, "max": 571.0909366607666, "sum": 571.0909366607666, "min": 571.0909366607666}, "check_early_stopping.time": {"count": 15, "max": 1.149892807006836, "sum": 13.535261154174805, "min": 0.804901123046875}, "setuptime": {"count": 1, "max": 25.966882705688477, "sum": 25.966882705688477, "min": 25.966882705688477}, "update.time": {"count": 15, "max": 8204.294919967651, "sum": 110102.2789478302, "min": 7072.367906570435}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1611596561.244288, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1611596449.129736}
#
#
# 2021-01-25 17:43:13 Completed - Training job completed
# ProfilerReport-1611596266: NoIssuesFound
# Training seconds: 151
# Billable seconds: 151

# %% [markdown]
# ## Set up hosting for the model
# Now that we've trained our model, we can deploy it behind an Amazon SageMaker real-time hosted endpoint.  This will allow out to make predictions (or inference) from the model dyanamically.
#
# _Note, Amazon SageMaker allows you the flexibility of importing models trained elsewhere, as well as the choice of not importing models if the target of model creation is AWS Lambda, AWS Greengrass, Amazon Redshift, Amazon Athena, or other deployment target._

# %%
linear_predictor = linear.deploy(initial_instance_count=1,
                                 instance_type='ml.t2.large')
# Out:
# ---------------!

# %% [markdown]
# ## Validate the model for use
# Finally, we can now validate the model for use.  We can pass HTTP POST requests to the endpoint to get back predictions.  To make this easier, we'll again use the Amazon SageMaker Python SDK and specify how to serialize requests and deserialize responses that are specific to the algorithm.

# %%
from sagemaker.predictor import csv_serializer, json_deserializer

#linear_predictor.content_type = 'text/csv'
linear_predictor.serializer = csv_serializer
linear_predictor.deserializer = json_deserializer

# %% [markdown]
# Now let's try getting a prediction for a single record.

# %%
result = linear_predictor.predict(train_set[0][30:31])
print(result)
# Out:
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# {'predictions': [{'score': 0.7760483026504517, 'predicted_label': 1}]}

# %% [markdown]
# OK, a single prediction works.  We see that for one record our endpoint returned some JSON which contains `predictions`, including the `score` and `predicted_label`.
#
#   * In this case, `score` will be a continuous value between [0, 1] representing the probability we think the digit is a `3` or not.
#
#   * `predicted_label` will take a value of either `0` or `1` where (somewhat counterintuitively) `1` denotes that we predict the image is a handwritten `3`, while a `predicted_label` of `0` denotes that we are predicting the image is not of a handwriten `3`.
#
# Let's do a whole batch of images and evaluate our predictive accuracy.

# %%
import numpy as np

predictions = []
for array in np.array_split(test_set[0], 100):
    result = linear_predictor.predict(array)
    predictions += [r['predicted_label'] for r in result['predictions']]

predictions = np.array(predictions)
# Out:
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
import pandas as pd

pd.crosstab(np.where(test_set[1] == 3, 1, 0), predictions, rownames=['actuals'], colnames=['predictions'])

# %% [markdown]
# As we can see from the confusion matrix above:
# * we predict ~870 images of `3` correctly (where actuals and predictions are both 1)
# * we predict ~140 images as `3`s that aren't actually `3`s (when actuals == 0 and predictions == 1)
# * and we miss predicting ~80 images of `3` (when actuals == 1 and predictions == 0).

# %% [markdown]
# ### Delete the Endpoint
#
# If you are finished with this notebook, please run the delete_endpoint() line in the cell below.  This will remove the hosted endpoint you created and avoid any charges from a stray instance being left on.

# %%
sagemaker.Session().delete_endpoint(linear_predictor.endpoint)
